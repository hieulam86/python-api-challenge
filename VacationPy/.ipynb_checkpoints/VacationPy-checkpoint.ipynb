# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
from pathlib import Path

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
csv_file = Path("../output_data/cities.csv")
city_data_df = pd.read_csv(csv_file)

#Convert Max Temp column from Fahrenheit to Celsius
city_data_df["Max Temp"] = city_data_df["Max Temp"] - 273.15

# Display sample data
city_data_df.head()
# Out:
#    City_ID                    City      Lat       Lng  Max Temp  Humidity  \
# 0        0                altamira  -3.2033  -52.2064     25.31        73
# 1        1          margaret river -33.9500  115.0667     15.69        85
# 2        2            puerto ayora  -0.7393  -90.3518     24.19        92
# 3        3  hawaiian paradise park  19.5933 -154.9731     22.73        91
# 4        4              georgetown   5.4112  100.3354     30.96        66
#
#    Cloudiness  Wind Speed Country        Date
# 0          31        2.04      BR  1693134693
# 1          61        5.83      AU  1693134715
# 2          77        2.24      EC  1693134716
# 3         100        2.06      US  1693134716
# 4          20        1.03      MY  1693134560

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
coordinates = {
    "Lat": (city_data_df["Lat"]),
    "Lng": (city_data_df["Lng"]),
    "City": (city_data_df["City"]),
    "Humidity": (city_data_df["Humidity"])
}

coordinates_df = pd.DataFrame(coordinates)

map_plot = coordinates_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    color = "City"  
)

# Display the map
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
max_temp = (city_data_df["Max Temp"] < 27) & (city_data_df["Max Temp"] > 21)
wind_speed = city_data_df["Wind Speed"] < 4.5
cloudiness = city_data_df["Cloudiness"] == 0

ideal_city_df = city_data_df[max_temp & wind_speed & cloudiness]

# Drop any rows with null values
ideal_city_df = ideal_city_df.dropna()

# Display sample data
ideal_city_df.head()
# Out:
#      City_ID              City      Lat       Lng  Max Temp  Humidity  \
# 164      164          elk city  35.4120  -99.4043     21.99        88
# 184      184          karratha -20.7377  116.8463     22.93        61
# 193      193  kill devil hills  36.0307  -75.6760     25.55        98
# 318      318       porto velho  -8.7619  -63.9039     26.03        73
# 363      363         boa vista   2.8197  -60.6733     26.99        83
#
#      Cloudiness  Wind Speed Country        Date
# 164           0        4.12      US  1693134780
# 184           0        3.70      AU  1693134792
# 193           0        0.00      US  1693134796
# 318           0        3.60      BR  1693134847
# 363           0        1.03      BR  1693134866

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_city_df.copy()
hotel_df = pd.DataFrame(ideal_city_df, columns=["City", "Country", "Lat", "Lng", "Humidity"])

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df.head()
# Out:
#                  City Country      Lat       Lng  Humidity Hotel Name
# 164          elk city      US  35.4120  -99.4043        88
# 184          karratha      AU -20.7377  116.8463        61
# 193  kill devil hills      US  36.0307  -75.6760        98
# 318       porto velho      BR  -8.7619  -63.9039        73
# 363         boa vista      BR   2.8197  -60.6733        83

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "apiKey": geoapify_key,
    "radius": radius
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row["Lat"]
    lng = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lat},{lng}"
    params["bias"] = f"circle:{lat},{lng}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    response = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = response.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# elk city - nearest hotel: No hotel found
# karratha - nearest hotel: No hotel found
# kill devil hills - nearest hotel: No hotel found
# porto velho - nearest hotel: No hotel found
# boa vista - nearest hotel: No hotel found
# marshall - nearest hotel: No hotel found
# acapulco de juarez - nearest hotel: No hotel found
# malibu - nearest hotel: No hotel found
# newman - nearest hotel: No hotel found
# lethem - nearest hotel: No hotel found
#                    City Country      Lat       Lng  Humidity      Hotel Name
# 164            elk city      US  35.4120  -99.4043        88  No hotel found
# 184            karratha      AU -20.7377  116.8463        61  No hotel found
# 193    kill devil hills      US  36.0307  -75.6760        98  No hotel found
# 318         porto velho      BR  -8.7619  -63.9039        73  No hotel found
# 363           boa vista      BR   2.8197  -60.6733        83  No hotel found
# 395            marshall      US  34.3834  -86.3333        92  No hotel found
# 406  acapulco de juarez      MX  16.8634  -99.8901        89  No hotel found
# 516              malibu      US  34.0050 -118.8101        54  No hotel found
# 518              newman      US  37.3138 -121.0208        78  No hotel found
# 525              lethem      GY   3.3803  -59.7968        67  No hotel found

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
hotel_map = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo=True,
    tiles="OSM",
    frame_width=700,
    frame_height=500,
    size="Humidity",
    color="City",
    hover_cols=["City", "Country", "Hotel Name"]
)

# Display the map
hotel_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Country,Hotel Name)
